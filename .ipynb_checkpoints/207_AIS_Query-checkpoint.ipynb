# %% [markdown]
# BEFORE RUNNING THIS NOTEBOOK:
#
# The tiles for training the first model can be downloaded from github in two zip files ('relabeled_tiles_pt1/2'), then unzipped and saved into a folder in the notebook directory called 'Relabeled_tiles'. Alternatively, if the notebook finds this folder empty, it will automatically download the tiles from Google Cloud (but it takes a few minutes).

# %%
# !pip install datalab
import cv2
import math
import pandas as pd
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from geopy.distance import geodesic
import google.datalab.bigquery as bq
import json
import numpy as np
# Out:
# Requirement already satisfied: datalab in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (1.2.0)
# Requirement already satisfied: requests>=2.9.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (2.25.1)
# Requirement already satisfied: pytz>=2015.4 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (2020.5)
# Requirement already satisfied: google-api-python-client>=1.6.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (2.1.0)
# Requirement already satisfied: jsonschema>=2.6.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (3.2.0)
# Requirement already satisfied: seaborn>=0.7.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.11.1)
# Requirement already satisfied: configparser>=3.5.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (5.0.2)
# Requirement already satisfied: future>=0.16.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.18.2)
# Requirement already satisfied: psutil>=4.3.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (5.8.0)
# Requirement already satisfied: ipykernel>=4.5.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (5.4.2)
# Requirement already satisfied: pandas>=0.22.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (1.2.0)
# Requirement already satisfied: urllib3>=1.22 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (1.26.2)
# Requirement already satisfied: scikit-image>=0.13.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.18.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (2.8.1)
# Requirement already satisfied: google-cloud-monitoring==0.31.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.31.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (1.15.0)
# Requirement already satisfied: httplib2>=0.10.3 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.19.1)
# Requirement already satisfied: google-api-core>=1.10.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (1.26.3)
# Requirement already satisfied: pandas-profiling==1.4.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (1.4.0)
# Requirement already satisfied: pyyaml>=3.11 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (5.4.1)
# Requirement already satisfied: plotly>=1.12.5 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (4.14.3)
# Requirement already satisfied: oauth2client>=2.2.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (4.1.3)
# Requirement already satisfied: mock>=2.0.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (4.0.3)
# Requirement already satisfied: scikit-learn>=0.18.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from datalab) (0.24.1)
# Requirement already satisfied: matplotlib>=1.4 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from pandas-profiling==1.4.0->datalab) (3.3.3)
# Requirement already satisfied: jinja2>=2.8 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from pandas-profiling==1.4.0->datalab) (2.11.2)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-core>=1.10.0->datalab) (54.2.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-core>=1.10.0->datalab) (1.28.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-core>=1.10.0->datalab) (20.8)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-core>=1.10.0->datalab) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-core>=1.10.0->datalab) (3.15.8)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-core>=1.10.0->datalab) (1.37.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-api-python-client>=1.6.2->datalab) (3.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core>=1.10.0->datalab) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core>=1.10.0->datalab) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core>=1.10.0->datalab) (4.7.2)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from httplib2>=0.10.3->datalab) (2.4.7)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.2->datalab) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.2->datalab) (6.1.7)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.2->datalab) (7.19.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.2->datalab) (6.1)
# Requirement already satisfied: pickleshare in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (0.18.0)
# Requirement already satisfied: decorator in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (4.4.2)
# Requirement already satisfied: pygments in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (2.7.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (3.0.9)
# Requirement already satisfied: colorama in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (0.4.4)
# Requirement already satisfied: backcall in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.0.0->ipykernel>=4.5.2->datalab) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=4.5.2->datalab) (0.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.8->pandas-profiling==1.4.0->datalab) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6.0->datalab) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6.0->datalab) (20.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=1.4->pandas-profiling==1.4.0->datalab) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=1.4->pandas-profiling==1.4.0->datalab) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=1.4->pandas-profiling==1.4.0->datalab) (8.1.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=1.4->pandas-profiling==1.4.0->datalab) (1.19.5)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from oauth2client>=2.2.0->datalab) (0.4.8)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from plotly>=1.12.5->datalab) (1.3.3)
# Requirement already satisfied: wcwidth in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=4.5.2->datalab) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.9.1->datalab) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.9.1->datalab) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.9.1->datalab) (4.0.0)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.13.0->datalab) (2.9.0)
# Requirement already satisfied: networkx>=2.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.13.0->datalab) (2.5.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.13.0->datalab) (1.1.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.13.0->datalab) (2021.4.8)
# Requirement already satisfied: scipy>=1.0.1 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.13.0->datalab) (1.6.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.18.2->datalab) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.18.2->datalab) (2.1.0)
# Requirement already satisfied: ipython-genutils in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from traitlets>=4.1.0->ipykernel>=4.5.2->datalab) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client->ipykernel>=4.5.2->datalab) (4.7.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client->ipykernel>=4.5.2->datalab) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ejhas\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel>=4.5.2->datalab) (300)

# %%
# Create needed folders and load Google credentials for GCP
if not os.path.exists('divided_documents'):
    os.makedirs('divided_documents')
if not os.path.exists('Relabeled_tiles'):
    os.makedirs('Relabeled_tiles')
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="elegant-weaver-287722-1c18abef2983.json"

# %% [markdown]
# #IMAGE SPLIT FUNCTION

# %%
def cut_tiles(raw_image, dim):
  
  # adjustments for image irregularity -----manipulate at your peril----
  xspan_adj = .0335
  yspan_adj = .03
  #---------------------------------------------------------------------

  # raw image corner coordinates
  
  coords_1 = (37.783639, -122.415728)
  coords_2 = (37.783639, -122.320053 - xspan_adj)
  coords_3 = (37.783639, -122.415728)
  coords_4 = (37.736021 - yspan_adj, -122.415728)

  width = geodesic(coords_1, coords_2).m
  height = geodesic(coords_3, coords_4).m
  print(width)
  print(height)


  #kaggle scene
  img = raw_image


  width_pixel = width/img.shape[0]
  height_pixel = height/img.shape[1] 

  #EMPTY FOLDER
  import glob
  clear = 1

  if clear == 1:
    tile_files = 'divided_documents'
    filelist = [f for f in os.listdir(tile_files) if f.endswith(".png") ]
    for f in filelist:
      os.remove(os.path.join(tile_files, f))


  # Dim is the dimension of the images we want to split into
  dim = 80
  r_earth = 6371000.0 #radius of earth estimate in meters
  latitude, longitude = coords_1 #start from top left as the image is read right-down
  dx, dy = 0, 0
  lat_longs = {}


  for r in range(0,img.shape[0],dim):#latitude
      dy = height_pixel*r
      new_latitude = latitude - (dy / r_earth) * (180 / math.pi)
      for c in range(0,img.shape[1],dim):#longitude
          dx = width_pixel*c
          new_longitude = longitude + (dx / r_earth) * (180 /math.pi) / math.cos(latitude * math.pi/180)
          # uncomment the following line to save the split images
          cv2.imwrite(f"divided_documents/img{r}_{c}.png",img[r:r+dim, c:c+dim,:])
          # start from top left and go right and downward
          lat_longs[f"img{r}_{c}.png"] = (new_latitude, new_longitude)
        
  # os.getcwd()
  #images here: https://drive.google.com/drive/folders/1MZmtRpCeR0EtaI9eJTbfCLi8capvSUsQ?usp=sharing
#   test00 = plt.imread('divided_documents/img0_0.png')
  return(lat_longs)
raw_image = cv2.imread('sfbay_1.png')
dim = 80

#run function
lat_longs = cut_tiles(raw_image, dim)
# Out:
# 5476.988450990182
# 8614.950171927141

# %%
def download_tiles():
    # !pip install --upgrade google-cloud-storage
    from google.cloud import storage
    storage_client = storage.Client("elegant-weaver-287722")
    # Create a bucket object
    bucket = storage_client.get_bucket('relabeled_tiles')
    
    prefix = 'Relabeled_tiles/'
#     dl_dir = 'Relabeled_tiles/'
    blobs = bucket.list_blobs(prefix=prefix)  # Get list of files
    for blob in blobs:
         filename = blob.name
#          filename = blob.name.replace('/', '_')
         blob.download_to_filename(filename)  # Download

# %% [markdown]
# #SHIP/NO SHIP MODEL

# %%
data=json.load(open("shipsnet.json"))

# %%
data.keys()
# Out:
# dict_keys(['data', 'labels', 'locations', 'scene_ids'])

# %%
train=data["data"]
label=data["labels"]
ids = data["scene_ids"]

# %%
#Get training tiles for model
from os import listdir
from os.path import isfile, join
import re
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split

# Check whether the folder of training tile folder exists and is populated
check_file = 'Relabeled_tiles/0__20150718_184300_090b__-122.35324421973536_37.772113980272394.png' 
isFile = os.path.isfile(check_file) 

#Download files if needed (this may take a while)
if isFile == False:
    download_tiles()

relabeled_tile_path = 'Relabeled_tiles'
files = [f for f in listdir(relabeled_tile_path) if isfile(join(relabeled_tile_path, f))]
x = []
y = []
for file in files:
  label = file.split('_')[0] 
  y.append(label)
  xtile = plt.imread(relabeled_tile_path + '/' + str(file))
  x.append(xtile)
  # print(xtile.shape)
# print(file)
x = np.array(x)
print(x.shape)
label = np.array(label)
plt.imshow(x[1])
plt.show()
x_flat = x.reshape(len(x),-1)
train_data, val_data, train_y, val_y = train_test_split(x_flat, y, test_size=0.2, random_state=43)
# Out:
# (4000, 80, 80, 3)

# %%
from sklearn.ensemble import RandomForestClassifier

sv=RandomForestClassifier(n_estimators=10)

sv.fit(train_data,train_y)

pre=sv.predict(val_data)

from sklearn.metrics import classification_report
print (classification_report(val_y,pre))

from sklearn.metrics import accuracy_score
print ("Accuracy:",accuracy_score(val_y,pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       426
#            1       0.89      0.78      0.83       374
#
#     accuracy                           0.85       800
#    macro avg       0.86      0.85      0.85       800
# weighted avg       0.85      0.85      0.85       800
#
# Accuracy: 0.85125

# %%
import sklearn
C2=sklearn.metrics.confusion_matrix(list(pre), list(val_y), sample_weight=None)
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
# plt.rcParams['axes.unicode_minus'] = False
sns.set()
f,ax=plt.subplots()

sns.heatmap(C2,annot=True,ax=ax,cmap="OrRd", fmt='.20g') #heatmap
ax.set_title('confusion matrix') #title
plt.rcParams['font.sans-serif'] = ['SimHei']

# plt.savefig('filename_single.png',dpi=600)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #SHIP/NO SHIP MODEL WITH LIVE DATA

# %%
 #Collect full image tiles (not partials on the border)
 
mypath2 = 'divided_documents'
files2 = [f for f in listdir(mypath2) if isfile(join(mypath2, f))]
search_tiles = []
search_tile_labels = []

for file in files2:
    img2 = plt.imread(mypath2 + '/' + str(file))

    if img2.shape == (80, 80, 3):
        search_tiles.append(img2)
        search_tile_labels.append(str(file))
search_tiles = np.array(search_tiles)
# # plt.imshow(x2[3])
# # plt.show()
search_tiles_flat = search_tiles.reshape(len(search_tiles),-1)

# %%
pred = sv.predict(search_tiles_flat)
probs = sv.predict_proba(search_tiles_flat)
len(pred[pred != '0'])
hit_index = []
for i in range(len(pred)):
  if pred[i] == '1':
      # print(i)
      hit_index.append(i)
print(len(hit_index))
print(hit_index)

## INDEX BASED ON SELECTION OF SEARCH TILES (NOT FULL FOLDER)!!
# Out:
# 23
# [21, 72, 82, 117, 121, 142, 161, 178, 250, 285, 348, 354, 355, 464, 468, 506, 523, 588, 594, 631, 644, 664, 667]

# %%
#Create list of tiles believed to contain ships
ship_tiles = []
for i in hit_index:
  ship_tiles.append(search_tile_labels[i])


#  Show predicted ship tiles with probability
print(len(hit_index))
fig, ax = plt.subplots(nrows = 1 + int(len(hit_index)/10), ncols = 10, sharex=True, sharey=True, figsize = (14, 10))
ax = ax.flatten()
for i in range(len(hit_index)):
    ax[i].imshow(search_tiles[hit_index[i]])
    ax[i].text(0,15,max(probs[hit_index[i]]), color = 'yellow' )
    ax[i].axis('off')
    ax[i].set(facecolor = 'black')
fig.suptitle("Predicted ships with indicated probability", fontsize=18, c = 'white')
fig.set_facecolor('black')
plt.show()
# Out:
# 23
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #AIS QUERY

# %%
#(function) build query for AIS

# 2016-08-31T00:00:00.000Z  to 2016-09-01T00:00:00.000Z

####Set ROUND value of RLAT, RLON to control coordinate precision
def make_query(vessel_num, ship_tiles, lat_longs):
  
  vessel_image = ship_tiles[vessel_num]

  # set parameters
  v_lat_long = lat_longs[vessel_image]
  lat = v_lat_long[0]
  lon = v_lat_long[1]

  #set minimum vessel length
  min_len = 200


  #set lat and lon tolerance (ideal range .005)
  lat_range = .005
  lon_range = .01
  #set image date (month, day, year)
  date = (7, 19, 2017)
  month, day, year = date
  #set time range if timestamp unknown (+/-; 0 for exact)
  day_range = 1
  month_range = 0
  year_range = 0

  print(v_lat_long)

  #build query
  a = 'SELECT DISTINCT VesselName, Callsign, VesselType, Month, Day, Year, Hour, Heading, Status, Length, RLAT, RLON, \
  FROM (SELECT *, FROM (SELECT *, EXTRACT(HOUR FROM BaseDateTime) AS hour, EXTRACT(DAY FROM BaseDateTime) AS day, EXTRACT(MONTH FROM BaseDateTime) AS month, EXTRACT(YEAR FROM BaseDateTime) AS year, \
  ROUND(LAT, 3) AS RLAT, ROUND(LON, 3) AS RLON, \
  FROM `elegant-weaver-287722.207Final.COMPOSITE_AIS`) WHERE day >= '            
  day_min = str(day - day_range)
  b = ' AND day <=  '
  day_max = str(day + day_range)
  c = ' AND month >= '
  month_min = str(month - month_range)
  d = ' AND month <= '
  month_max = str(month + month_range)
  e = ' AND year >= '
  year_min = str(year - year_range)
  f = ' AND year <= '
  year_max = str(year + year_range)
  g = ' AND LAT > '
  lat_min = str(lat - lat_range)
  h = ' AND LAT < '
  lat_max = str(lat + lat_range)
  i = ' AND LON > '
  lon_min = str(lon - lon_range)
  j = ' AND LON < '
  lon_max = str(lon + lon_range)
  k = ' AND Length > '
  min_len = str(min_len)
  l = ') LIMIT '
  limit = str(100000)

  query = a + day_min + b + day_max + c + month_min + d + month_max + e + year_min + f + year_max + g + lat_min + h + lat_max + i + lon_min + j + lon_max + k + min_len + l + limit
#   print(query)
  return(query)

# %% [markdown]
# #KNN SHIP IDENTIFICATION

# %%
def knn_id(ais_df, lat_longs, ship_tiles, vessel_num):
  if ais.empty:
    return('UNCONFIRMED VESSEL')
  
  #KNN Setup
  feature_set = ['RLAT', 'RLON']
  train_data = []
  for i in range (len(ais[['RLAT']])):
    features = []
    features.append(ais.at[i, feature_set[0]])
    features.append(ais.at[i, feature_set[1]])
    train_data.append(features)

  train_labels = []
  for i in range (len(ais[['VesselName']])):
    train_labels.append(ais.at[i,'VesselName'])

  dev_data = []
  inner_data = []
  inner_data.append(lat_longs[ship_tiles[vessel_num]][0])
  inner_data.append(lat_longs[ship_tiles[vessel_num]][1])
  dev_data.append(inner_data)

  #KNN
  knn = KNeighborsClassifier(n_neighbors = 5, p = 2, metric='minkowski')
  knn.fit(train_data, train_labels)
  y_pred = knn.predict(dev_data)
  # error = (dev_labels != y_pred).sum()/len(y_pred)
  return(y_pred)

# %%
# query
# https://marinecadastre.gov/ais/
# https://marinecadastre.gov/img/data-dictionary.jpg


vessel_num = 0
vessel_names = []

pd.set_option('display.max_rows', 1000000)

# general = 'SELECT * FROM `elegant-weaver-287722.207Final.COMPOSITE_AIS` LIMIT 10'
# query = general
for i in range(len(ship_tiles)):
# for i in range(2):
  vessel_num = i
  query = make_query(vessel_num, ship_tiles, lat_longs)

  df = bq.Query(query).execute().result().to_dataframe()
  try:
    ais = df[df['VesselName'].notnull()].reset_index()
  # print(ais['VesselName'].unique())
  # print(len(ais['VesselName']))
#   print(ais[['VesselName']])
  except KeyError:
    ais = pd.DataFrame()
  # ais
  try:
    name = knn_id(ais, lat_longs, ship_tiles, vessel_num)
  except ValueError:
    name = 'UNCONFIRMED VESSEL'
  print(name)
  vessel_names.append(name)
# Out:
# (37.783639, -122.328749354711)
# UNCONFIRMED VESSEL
# (37.75292280841646, -122.37644732148239)
# UNCONFIRMED VESSEL
# (37.75292280841646, -122.35119545672106)
# ['LIBERTY BAY']
# (37.75072879473192, -122.35119545672106)
# ['LIBERTY BAY']
# (37.75072879473192, -122.33997240571603)
# ['ASTRO PHOENIX']
# (37.74853478104738, -122.37644732148239)
# UNCONFIRMED VESSEL
# (37.74853478104738, -122.328749354711)
# UNCONFIRMED VESSEL
# (37.746340767362845, -122.37364155873112)
# UNCONFIRMED VESSEL
# (37.74195273999376, -122.3680300332286)
# ['CAPE MOHICAN']
# (37.739758726309226, -122.3680300332286)
# ['CAPE MOHICAN']
# (37.779250972630926, -122.38486460973616)
# UNCONFIRMED VESSEL
# (37.73756471262469, -122.37083579597986)
# ['CAPE MOHICAN']
# (37.73756471262469, -122.3680300332286)
# ['CAPE MOHICAN']
# (37.77266893157731, -122.35961274497483)
# ['HON HENRY JACKMAN']
# (37.77266893157731, -122.34838969396979)
# ['SEAWAYS LEYTE']
# (37.77047491789277, -122.33997240571603)
# ['SEAWAYS LEYTE']
# (37.77047491789277, -122.38486460973616)
# ['CAPE HUDSON']
# (37.76608689052369, -122.39608766074119)
# UNCONFIRMED VESSEL
# (37.76608689052369, -122.3820588469849)
# ['HORIZON SPIRIT']
# (37.76169886315461, -122.37925308423364)
# ['HORIZON SPIRIT']
# (37.76169886315461, -122.34558393121854)
# ['CSL TECUMSEH']
# (37.76169886315461, -122.3820588469849)
# ['HORIZON SPIRIT']
# (37.78144498631546, -122.37644732148239)
# ['YM MANDATE']

# %% [markdown]
# #DISPLAY

# %%
fig, ax = plt.subplots(figsize=(20,20))

for tile in range(len(ship_tiles)):
  y_num = int(ship_tiles[tile][3:].split('_')[0])
  x_num = int(ship_tiles[tile][3:].split('_')[1].split('.')[0])
  # print(ship_tiles[tile], x_num, y_num)
  ax.text(x_num + dim/3, y_num + dim/2,vessel_names[tile], color = 'yellow' )

grid_on = 0
ax.set_xticks(range(0, raw_image.shape[1], 80)) 
ax.set_yticks(range(0, raw_image.shape[0], 80)) 
if grid_on == 0:
    ax.grid(False) 

ax.imshow(plt.imread('sfbay_1.png'))
plt.show()

#save output
fig.savefig('output.png')
